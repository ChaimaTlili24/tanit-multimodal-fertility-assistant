# %% [markdown]
# # Tanit Multimodal Fertility Assistant – Kaggle Demo
#
# Ce notebook montre comment :
#
# 1. Installer les dépendances du projet.
# 2. Lancer l’interface Gradio (chatbot multimodal).
# 3. Tester rapidement le backend (STT + RAG simulé) par code.
#
# Ce prototype est réalisé pour l’assignement **“Multimodal Gen AI Intern (VLM / LLM / Voice)”** chez Tanit.ai.
